# %%
import urllib.request
import pandas as pd

def download_data(url):
    with urllib.request.urlopen(url) as response:
        data = response.read().decode('utf-8')
    return data

def convert_to_csv(data, output_file):
    # Read JSON data into a DataFrame
    df = pd.read_json(data)

    # Save DataFrame to CSV
    df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}.")

url = 'https://data.nasa.gov/resource/y77d-th95.json'
output_file = 'nasa_data.csv'

    # Download the data
json_data = download_data(url)

    # Convert to CSV
convert_to_csv(json_data, output_file)
# Out:
# Data saved to nasa_data.csv.

# %%
data = pd.read_csv('/content/nasa_data.csv')

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....
#
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN

# %%
import pandas as pd
from pandas.io.json import json_normalize
import ast

# %%
data['geolocation'] = data['geolocation'].apply(ast.literal_eval)
data[['geolocation_type', 'geolocation_coordinates']] = pd.json_normalize(data['geolocation'])
data.drop('geolocation', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9295f0d9f47c> in <cell line: 1>()
# ----> 1 data['geolocation'] = data['geolocation'].apply(ast.literal_eval)
#       2 data[['geolocation_type', 'geolocation_coordinates']] = pd.json_normalize(data['geolocation'])
#       3 data.drop('geolocation', axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/lib/python3.10/ast.py in literal_eval(node_or_string)
#     108                     return left - right
#     109         return _convert_signed_num(node)
# --> 110     return _convert(node_or_string)
#     111
#     112
#
# /usr/lib/python3.10/ast.py in _convert(node)
#     107                 else:
#     108                     return left - right
# --> 109         return _convert_signed_num(node)
#     110     return _convert(node_or_string)
#     111
#
# /usr/lib/python3.10/ast.py in _convert_signed_num(node)
#      81             else:
#      82                 return - operand
# ---> 83         return _convert_num(node)
#      84     def _convert(node):
#      85         if isinstance(node, Constant):
#
# /usr/lib/python3.10/ast.py in _convert_num(node)
#      72     def _convert_num(node):
#      73         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74             _raise_malformed_node(node)
#      75         return node.value
#      76     def _convert_signed_num(node):
#
# /usr/lib/python3.10/ast.py in _raise_malformed_node(node)
#      69         if lno := getattr(node, 'lineno', None):
#      70             msg += f' on line {lno}'
# ---> 71         raise ValueError(msg + f': {node!r}')
#      72     def _convert_num(node):
#      73         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
#
# ValueError: malformed node or string: nan

# %%
data = data.dropna(subset=['geolocation'])

# %%
data['geolocation'] = data['geolocation'].apply(ast.literal_eval)
data[['geolocation_type', 'geolocation_coordinates']] = pd.json_normalize(data['geolocation'])
data.drop('geolocation', axis=1, inplace=True)
# Out:
# <ipython-input-9-9295f0d9f47c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['geolocation'] = data['geolocation'].apply(ast.literal_eval)
# <ipython-input-9-9295f0d9f47c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['geolocation_type', 'geolocation_coordinates']] = pd.json_normalize(data['geolocation'])
# <ipython-input-9-9295f0d9f47c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['geolocation_type', 'geolocation_coordinates']] = pd.json_normalize(data['geolocation'])
# <ipython-input-9-9295f0d9f47c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('geolocation', axis=1, inplace=True)

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  :@computed_region_cbhk_fwbd  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333                          NaN
# 1  1951-01-01T00:00:00.000  56.18333   10.23333                          NaN
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000                          NaN
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000                          NaN
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000                          NaN
#
#    :@computed_region_nnqa_25f4 geolocation_type geolocation_coordinates
# 0                          NaN            Point       [6.08333, 50.775]
# 1                          NaN            Point    [10.23333, 56.18333]
# 2                          NaN            Point        [-113, 54.21667]
# 3                          NaN            Point       [-99.9, 16.88333]
# 4                          NaN            Point     [-64.95, -33.16667]

# %%
# Convert the "geolocation" column from JSON to separate columns

data[['longitude', 'latitude']] = data['geolocation_coordinates'].apply(pd.Series)
data.drop(['geolocation_coordinates'], axis=1, inplace=True)
# Out:
# <ipython-input-11-51a8a31d07b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['longitude', 'latitude']] = data['geolocation_coordinates'].apply(pd.Series)
# <ipython-input-11-51a8a31d07b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['longitude', 'latitude']] = data['geolocation_coordinates'].apply(pd.Series)
# <ipython-input-11-51a8a31d07b2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['geolocation_coordinates'], axis=1, inplace=True)

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  :@computed_region_cbhk_fwbd  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333                          NaN
# 1  1951-01-01T00:00:00.000  56.18333   10.23333                          NaN
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000                          NaN
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000                          NaN
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000                          NaN
#
#    :@computed_region_nnqa_25f4 geolocation_type  longitude  latitude
# 0                          NaN            Point    6.08333  50.77500
# 1                          NaN            Point   10.23333  56.18333
# 2                          NaN            Point -113.00000  54.21667
# 3                          NaN            Point  -99.90000  16.88333
# 4                          NaN            Point  -64.95000 -33.16667

# %%
data['year'] = pd.to_datetime(data['year'], errors='coerce')
data['year'] = data['year'].dt.strftime('%Y-%m-%d')
# Out:
# <ipython-input-13-ea01f8a26ae9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = pd.to_datetime(data['year'], errors='coerce')
# <ipython-input-13-ea01f8a26ae9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year'] = data['year'].dt.strftime('%Y-%m-%d')

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass  fall        year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880-01-01  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951-01-01  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952-01-01  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976-01-01  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902-01-01 -33.16667
#
#      reclong  :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  \
# 0    6.08333                          NaN                          NaN
# 1   10.23333                          NaN                          NaN
# 2 -113.00000                          NaN                          NaN
# 3  -99.90000                          NaN                          NaN
# 4  -64.95000                          NaN                          NaN
#
#   geolocation_type  longitude  latitude
# 0            Point    6.08333  50.77500
# 1            Point   10.23333  56.18333
# 2            Point -113.00000  54.21667
# 3            Point  -99.90000  16.88333
# 4            Point  -64.95000 -33.16667
